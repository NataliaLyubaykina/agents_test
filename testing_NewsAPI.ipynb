# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaLyubaykina/agents_test/blob/main/testing_NewsAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Parsing
#
# Apparently, most financial news websites **do not provide full or free APIs**.
# Some sites have **no public API at all**, and others place most of their content **behind paywalls**.
#
# There are tools, in this notebook I test [NewsAPI.org](https://newsapi.org/).

# %% [markdown]
# # Testing NewsAPI.org to aggregate news

# %% [markdown]
# ## How many sources can it aggregate for economic news from the US?

# %%
import requests
import pandas as pd

url = f"https://newsapi.org/v2/top-headlines/sources?apiKey={API_KEY}"

response = requests.get(url)
data = response.json()

if response.status_code != 200:
    print("Error:", data)
else:
    sources = data.get("sources", [])
    df = pd.DataFrame([{
        "id": s["id"],
        "name": s["name"],
        "category": s["category"],
        "language": s["language"],
        "country": s["country"],
        "url": s["url"],
        "description": s["description"]
    } for s in sources])

    # Filter for US + English
    df = df[(df["country"] == "us") & (df["language"] == "en")]

    # Keep relevant categories
    df = df[df["category"].isin(["business", "general", "technology", "science"])]

    # Manually tag most relevant economic/financial outlets
    relevance_keywords = [
        "finance", "business", "market", "money",
        "economy", "financial", "investment", "stock"
    ]

    df["is_economic"] = df["description"].str.contains(
        "|".join(relevance_keywords), case=False, na=False
    )

    econ_df = df[df["is_economic"]].copy()

    # Sort by category for overview
    econ_df = econ_df.sort_values(["category", "name"])
    econ_df = econ_df.reset_index(drop=True)

# %%
econ_df['id']
# Out:
# 0               bloomberg
# 1        business-insider
# 2                 fortune
# 3        associated-press
# 4                fox-news
# 5                nbc-news
# 6                newsweek
# 7                 reuters
# 8     the-washington-post
# 9             hacker-news
# 10           the-next-web
# 11                  wired
# Name: id, dtype: object

# %% [markdown]
# # Twelve sources - not bad

# %% [markdown]
# ## How many news for today can it agreggate from these sources?

# %%
from datetime import datetime, timezone, timedelta

# 🗓️ Get today's date in UTC (ISO 8601 compatible)
today = datetime.now(timezone.utc).strftime("%Y-%m-%d")
print(today)
# Out:
# 2025-11-05

# %%
# 🗞️ Collect all articles from your econ_df
all_articles = []

print(f"Fetching today's news ({today}) from {len(econ_df)} economic/financial sources...\n")

for source_id, source_name in zip(econ_df["id"], econ_df["name"]):
    url = (
        f"https://newsapi.org/v2/top-headlines?"
        f"sources={source_id}&"
        f"language=en&"
        f"pageSize=100&"
        f"apiKey={API_KEY}"
    )

    response = requests.get(url)
    data = response.json()

    if response.status_code != 200:
        print(f"❌ {source_name} ({source_id}): Error {response.status_code} → {data.get('message')}")
        continue

    articles = data.get("articles", [])
    print(f"✅ {source_name}: {len(articles)} articles")

    for a in articles:
        all_articles.append({
            "source_id": source_id,
            "source_name": source_name,
            "title": a["title"],
            "description": a["description"],
            "url": a["url"],
            "publishedAt": a["publishedAt"]
        })
# Out:
# Fetching today's news (2025-11-05) from 12 economic/financial sources...
#
# ✅ Bloomberg: 10 articles
# ✅ Business Insider: 10 articles
# ✅ Fortune: 10 articles
# ✅ Associated Press: 10 articles
# ✅ Fox News: 10 articles
# ✅ NBC News: 10 articles
# ✅ Newsweek: 10 articles
# ✅ Reuters: 0 articles
# ✅ The Washington Post: 10 articles
# ✅ Hacker News: 10 articles
# ✅ The Next Web: 7 articles
# ✅ Wired: 10 articles

# %%
if all_articles:
    news_df = pd.DataFrame(all_articles)

    # ✅ robust timestamp parsing
    news_df["publishedAt"] = pd.to_datetime(news_df["publishedAt"], format="ISO8601", errors="coerce")

    news_df = news_df.sort_values("publishedAt", ascending=False).reset_index(drop=True)

    print(f"\n✅ Total articles collected: {len(news_df)} from {news_df['source_name'].nunique()} sources.")
else:
    print("\n⚠️ No articles found for today.")
# Out:
# ✅ Total articles collected: 107 from 11 sources.

# %%
news_df.head()
# Out:
#    source_id source_name                                              title  \
# 0   fox-news    Fox News  The 2025 election that may determine if Republ...
# 1   fox-news    Fox News  FBI arrests 2 men in connection with Harvard M...
# 2  bloomberg   Bloomberg  YPF Hails Milei Agenda as Abu Dhabi Joins Arge...
# 3   fox-news    Fox News  Erika Kirk reveals her message to Jimmy Kimmel...
# 4   fox-news    Fox News  ‘Golden Bachelor’ star Gerry Turner admits mar...
#
#                                          description  \
# 0  California voters decide Proposition 50 Tuesda...
# 1  The FBI's Boston Field Office arrested two Mas...
# 2  State-run YPF SA said the oil and gas industry...
# 3  Erika Kirk says she doesn’t "need" Jimmy Kimme...
# 4  Gerry Turner opens up about his failed "Golden...
#
#                                                  url  \
# 0  https://www.foxnews.com/politics/2025-election...
# 1  https://www.foxnews.com/us/fbi-arrests-2-men-c...
# 2  https://www.bloomberg.com/news/articles/2025-1...
# 3  https://www.foxnews.com/media/erika-kirk-revea...
# 4  https://www.foxnews.com/entertainment/golden-b...
#
#                           publishedAt
# 0 2025-11-04 17:07:24.105661300+00:00
# 1 2025-11-04 17:07:19.619986200+00:00
# 2           2025-11-04 16:55:16+00:00
# 3 2025-11-04 16:52:22.479545700+00:00
# 4 2025-11-04 16:22:24.338996700+00:00

# %% [markdown]
# ## Can already see that many articles are relevant, some local news

# %% [markdown]
# # Analysing the aggregated news

# %% [markdown]
# ## News categories defined by GPT model (using fixed topic list)

# %% [markdown]
# ### Fixed categories

# %%
# possible topics
topics = [
    "Financial Markets",
     "Stock Markets",
    "Economic Policies",
    "Financial Regulations",
    "Inflation",
    "Labor Market",
    "Corporate Strategy",
    "Energy Sector",
    "Real Estate",
    "Consumer Insights",
    "Banking and Credit",
    "Technology Innovations",
    "Commodities",
    "Auto Industry Issues",
    "Political Dynamics",
    "Political Elections",
    "Social Issues",
    "International Relations",
    "Public Health Policies",
    "Entertainment News"
]

# %%
from openai import OpenAI
from tqdm import tqdm
import pandas as pd

client = OpenAI(api_key=my_gpt_key)

df = news_df.copy()
texts = (
    df["title"].fillna("") + ". " + df["description"].fillna("")
).tolist()

print(f"Using fixed {len(topics)} categories:\n{topics}\n")

# --- classification function ---
def classify_article(text, topics):
    prompt = f"""
You are an economics analyst.
Assign the following news item to the *closest* matching category from this list:
{', '.join(topics)}.

If it is not economic, financial, or business related, respond exactly with: "Other".
You must choose **exactly one** from the list if possible.

News:
{text}

Return only the category name exactly as in the list or "Not Economic".
"""
    r = client.chat.completions.create(
        model="gpt-4o-mini",
        temperature=0,  # 👈 stability: deterministic output
        messages=[{"role": "user", "content": prompt}],
    )
    return r.choices[0].message.content.strip()

# --- run classification ---
labels = []
for text in tqdm(texts, desc="Categorizing articles"):
    label = classify_article(text, topics)
    labels.append(label)

df["category"] = labels
print("✅ Classification complete.")
# Out:
# Using fixed 20 categories:
# ['Financial Markets', 'Stock Markets', 'Economic Policies', 'Financial Regulations', 'Inflation', 'Labor Market', 'Corporate Strategy', 'Energy Sector', 'Real Estate', 'Consumer Insights', 'Banking and Credit', 'Technology Innovations', 'Commodities', 'Auto Industry Issues', 'Political Dynamics', 'Political Elections', 'Social Issues', 'International Relations', 'Public Health Policies', 'Entertainment News']
# Categorizing articles: 100%|██████████| 107/107 [00:58<00:00,  1.84it/s]
# ✅ Classification complete.

# %%
from openai import OpenAI
import re, ast
from datetime import datetime

client = OpenAI(api_key=my_gpt_key)

# --- use the same cleaned df you already have ---
sample_texts = (
    df["title"].fillna("") + ". " + df["description"].fillna("")
).tolist()[:50]  # sample first 50 items for context

# ===============================================================
# 1️⃣  GPT defines categories based on current news headlines
# ===============================================================
prompt_infer = f"""
You are an economics analyst.
Given these news headlines, identify 8–12 short, clear economic or financial categories
that best represent the topics covered. Use 2–3 word labels.

Headlines:
{chr(10).join(sample_texts)}

Return only a valid Python list of strings (no commentary).
"""

resp_infer = client.chat.completions.create(
    model="gpt-4o-mini",
    temperature=0,
    messages=[{"role": "user", "content": prompt_infer}],
)
raw_infer = resp_infer.choices[0].message.content.strip()

# --- clean and parse list ---
raw_infer = re.sub(r"^```[a-zA-Z]*", "", raw_infer).replace("```", "").strip()
try:
    inferred_categories = ast.literal_eval(raw_infer)
except Exception:
    inferred_categories = [c.strip() for c in raw_infer.split(",") if c.strip()]

print(f"\n🧩 GPT-inferred categories ({len(inferred_categories)}):\n{inferred_categories}\n")

# ===============================================================
# 2️⃣  Ask GPT to compare inferred vs. fixed lists
# ===============================================================
prompt_compare = f"""
Compare these two lists of economic categories.

Fixed categories:
{topics}

Newly inferred categories from data:
{inferred_categories}

Analyze whether the fixed list sufficiently covers the new ones.
If some inferred categories are missing or too distinct,
recommend how the list of fixed categories {topics} should be optimized to better reflect today's news with minimal changes,
and keeping it not significantly longer than it is now.

Be concise, and finish with a clear yes/no about whether to expand the list.
"""#recommend which 1–3 additional categories (if any) should be added.

resp_compare = client.chat.completions.create(
    model="gpt-4o-mini",
    temperature=0,
    messages=[{"role": "user", "content": prompt_compare}],
)
conclusion = resp_compare.choices[0].message.content.strip()

print("### 🧠 Category Coverage Analysis\n")
print(conclusion)
# Out:
# 🧩 GPT-inferred categories (12):
# ['Political Elections', 'Healthcare Incidents', 'Energy Sector', 'Consumer Sentiment', 'Financial Services', 'Market Trends', 'Corporate Strategy', 'International Relations', 'Technology Innovations', 'Economic Policy', 'Labor Market', 'Tourism Industry']
#
# ### 🧠 Category Coverage Analysis
#
# The fixed categories cover many of the newly inferred categories, but there are some gaps and distinctions that should be addressed:
#
# 1. **Healthcare Incidents**: This is not explicitly covered in the fixed list. It could be integrated into "Public Health Policies" or added as a separate category.
#
# 2. **Consumer Sentiment**: This is somewhat related to "Consumer Insights," but it may warrant its own category to reflect the focus on consumer attitudes and behaviors.
#
# 3. **Financial Services**: This could be encompassed within "Banking and Credit," but it may be beneficial to explicitly include it to capture a broader range of financial activities.
#
# 4. **Market Trends**: This is a broader concept that could be included under "Economic Policies" or "Financial Markets," but it might be useful to have it as a distinct category to highlight current trends.
#
# 5. **Tourism Industry**: This is not covered in the fixed list and could be added as a new category, though it may be less critical compared to others.
#
# ### Recommendations for Optimization:
# - **Add**: "Healthcare Incidents" and "Tourism Industry" as new categories.
# - **Modify**: Consider renaming "Consumer Insights" to "Consumer Sentiment" to better reflect the inferred category.
# - **Add**: "Market Trends" as a new category to capture broader economic movements.
# - **Retain**: "Banking and Credit" can encompass "Financial Services," but consider explicitly mentioning "Financial Services" if space allows.
#
# ### Conclusion:
# To better reflect today's news while keeping the list concise, I recommend adding a few categories and slightly modifying existing ones.
#
# **Final Decision**: Yes, expand the list.

# %% [markdown]
# ## Summary for ecomomic news

# %%
df = df[df["category"] != "Other"].copy()
df = df.reset_index(drop=True)

# %%
from datetime import datetime, timedelta, timezone
import pandas as pd
from openai import OpenAI

# --- Setup ---
client = OpenAI(api_key=my_gpt_key)

# define filename with date
date_str = datetime.now().strftime("%Y-%m-%d")
filename = f"news_summary_for_{date_str}.txt"

# small helper: print + write
def tee_print(text="", end="\n"):
    """Print to console and also write to file."""
    print(text, end=end)
    with open(filename, "a", encoding="utf-8") as f:
        f.write(text + end)

# --- Time with timezone ---
tz_offset = timezone(timedelta(hours=1))  # set your offset here
current_time = datetime.now(tz=tz_offset).strftime("%Y-%m-%d %H:%M:%S (UTC+1)")

# --- Basic stats ---
total_econ = len(df)
source_counts = df["source_name"].value_counts().to_dict()
cat_counts = df["category"].value_counts()
cat_counts_dict = cat_counts.to_dict()

# --- Sort by most frequent categories ---
df["category"] = pd.Categorical(df["category"], categories=cat_counts.index, ordered=True)
df = df.sort_values("category")

# clear file first
open(filename, "w").close()

# --- HEADER ---
tee_print(f"### 🗓️ Daily Economic News Summary ({current_time})\n")
tee_print(f"Till this time today, NewsAPI aggregated **{total_econ} economic news items**.\n")

# --- SOURCES ---
tee_print("**Sources contributing (news count in brackets):**")
tee_print(", ".join([f"{src} ({n})" for src, n in source_counts.items()]))
tee_print()

# --- CATEGORIES ---
tee_print(f"GPT categorized them into **{len(cat_counts)} economic categories:**")
tee_print(", ".join([f"{cat} ({count})" for cat, count in cat_counts_dict.items()]))
tee_print()

# --- HEADLINES BY CATEGORY (prints only) ---
for cat in cat_counts.index:
    print(f"#### {cat} ({cat_counts_dict[cat]} news)\n")
    cat_df = df[df["category"] == cat]
    for _, row in cat_df.iterrows():
        print(f"- {row['title']} ({row['source_name']})")
    print()

# --- GPT SUMMARIES FOR TOP 3 CATEGORIES ---
top3 = cat_counts.head(3).index.tolist()

for cat in top3:
    cat_df = df[df["category"] == cat]
    headlines = "\n".join(cat_df["title"].tolist())

    prompt_summary = f"""
You are an economics journalist writing concise market briefs.
Read the following headlines about "{cat}" and produce a **short 2–3 sentence summary** only.

Summarize:
- What specifically happened today
- Why it matters economically
- What it could mean going forward

Use clear, factual language, keep it under 80 words total, and include key numbers or names if relevant.
Do NOT exceed three sentences.

Headlines:
{headlines}

Return only the summary text (no intro, no list, no formatting).
"""

    resp = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt_summary}],
    )

    summary = resp.choices[0].message.content.strip()
    tee_print(f"### 🧠 {cat} — Summary\n{summary}\n")

print(f"\n✅ Summary sections saved to: {filename}")
# Out:
# ### 🗓️ Daily Economic News Summary (2025-11-05 18:40:21 (UTC+1))
#
# Till this time today, NewsAPI aggregated **55 economic news items**.
#
# **Sources contributing (news count in brackets):**
# Bloomberg (8), The Next Web (7), Fortune (7), Fox News (6), Business Insider (6), Associated Press (5), Wired (5), The Washington Post (5), Hacker News (2), Newsweek (2), NBC News (2)
#
# GPT categorized them into **17 economic categories:**
# Technology Innovations (10), Political Dynamics (8), Political Elections (7), Corporate Strategy (5), Financial Markets (3), International Relations (3), Energy Sector (3), Stock Markets (3), Social Issues (2), Labor Market (2), Financial Regulations (2), Auto Industry Issues (2), Public Health Policies (1), Inflation (1), Consumer Insights (1), Real Estate (1), Economic Policies (1)
#
# #### Technology Innovations (10 news)
#
# - Sequoia PGP is now LGPL 2.0+ (Hacker News)
# - The EV Battery Tech That’s Worth the Hype, According to Experts (Wired)
# - The next Silicon Valley may not exist. Here’s what smaller hubs can do to attract VC dollars (Fortune)
# - 3D-printed rocket engine revs up for orbital launch in Scotland (The Next Web)
# - A metaverse network plots an escape from Meta's 'walled gardens' (The Next Web)
# - This startup gives your speech a new 'human-realistic' AI voice — for free (The Next Web)
# - Mobility giant Bolt adopts self-driving Starship robots for food delivery (The Next Web)
# - Blockchain giant Chainalysis acquires AI agent startup Alterya (Business Insider)
# - bigscience/T0pp · Hugging Face (Hacker News)
# - OpenAI Signs $38 Billion Deal With Amazon (Wired)
#
# #### Political Dynamics (8 news)
#
# - Inside the billionaire network shaping MAGA’s post-Trump future (The Washington Post)
# - Trump’s foe in tariffs case? A legal group funded by conservatives. (The Washington Post)
# - Boris Johnson has survived Partygate–and he’s coming for Northern Ireland (Fortune)
# - Dutch Parties to Begin Coalition Talks After Negotiator Pick (Bloomberg)
# - Trump Military Attack on Venezuelan Boat Intends To Redefine War | Opinion (Newsweek)
# - Government shutdown poised to become longest ever (Associated Press)
# - Conservatives erupt on social media over 'absurd' Pelosi comment calling Trump 'worst thing' on earth (Fox News)
# - The Inside Story of How Gen Z Toppled Nepal’s Leader and Chose a New One on Discord (Wired)
#
# #### Political Elections (7 news)
#
# - New Jersey, Virginia Republicans seek Trump energy (Associated Press)
# - What to watch on Election Day 2025 (Associated Press)
# - New York City voters choose new mayor after heated campaign (Associated Press)
# - The 2025 election that may determine if Republicans hold House in 2026 midterms (Fox News)
# - Americans flock to the polls for 2025 off-year elections on November 4 (Fox News)
# - Virginia to elect its first female governor in history-making vote (The Washington Post)
# - Five big questions for Trump and Democrats on Election Day 2025 (The Washington Post)
#
# #### Corporate Strategy (5 news)
#
# - 4 vital steps that U.S. CEOs must take in the economic battle with China (Fortune)
# - Unprofitable companies needed to be profitable yesterday (Fortune)
# - US Steel Says Japanese Ownership to Unlock $3 Billion in Value (Bloomberg)
# - Caterpillar Hikes Earnings Targets on Energy, Equipment Demand (Bloomberg)
# - Yum Brands begins strategic review for struggling Pizza Hut chain (NBC News)
#
# #### Financial Markets (3 news)
#
# - Trump's CZ Pardon Has the Crypto World Bracing for Impact (Wired)
# - Money-Market Stress Persists Ahead of Fed’s Portfolio Pivot (Bloomberg)
# - Why major financial firms are expanding Texas presence beyond traditional Wall Street hub (Fox News)
#
# #### International Relations (3 news)
#
# - Trump and Kim Jong Un will likely hold a summit next year, South Korea's spy agency says (NBC News)
# - Sudan Army Weighs US Truce Plan as UN Pleads for End to Violence (Bloomberg)
# - Venezuela Speaks Out on Trump's Drug Boat Attack: 'Murder' (Newsweek)
#
# #### Energy Sector (3 news)
#
# - US Utility Lobbying Jumps 14% Amid AI Boom, Clean Energy Turmoil (Bloomberg)
# - Gunvor and Lukoil: Oil Sanctions and Russian Ties Led to Deal of a Lifetime (Bloomberg)
# - YPF Hails Milei Agenda as Abu Dhabi Joins Argentina’s LNG Push (Bloomberg)
#
# #### Stock Markets (3 news)
#
# - US stocks open lower, weighed down by Big Tech (Associated Press)
# - Why investors shouldn't worry about stretched stock market valuations: BofA (Business Insider)
# - Buybacks vs dividends? In market downturns, the rules may change (Fortune)
#
# #### Social Issues (2 news)
#
# - No, SNAP Benefits Aren’t Mostly Used by Immigrants (Wired)
# - Why a former SoftBank partner is tackling mid-career drop-off for working mothers (Fortune)
#
# #### Labor Market (2 news)
#
# - 5 do's and don'ts to land a job in the private-credit boom (Business Insider)
# - Why middle managers are valuable to companies and their employees (Business Insider)
#
# #### Financial Regulations (2 news)
#
# - Rapid delivery giant Getir quits France, citing regulation hurdles (The Next Web)
# - Elon Musk crows as German authorities start treating greenwashing as fraud (Fortune)
#
# #### Auto Industry Issues (2 news)
#
# - EU's EV battery ambitions hang in the balance (The Next Web)
# - BMW and Porsche have a China problem. They're not the only ones. (Business Insider)
#
# #### Public Health Policies (1 news)
#
# - Gretchen Whitmer confronted on 'weird' COVID restrictions, says she did her best with poor information (Fox News)
#
# #### Inflation (1 news)
#
# - From groceries to gas, Americans say they’re spending more under Trump (The Washington Post)
#
# #### Consumer Insights (1 news)
#
# - 'Pawn Stars' boss Rick Harrison calls out the Vegas pricing that ticks 'people off' (Fox News)
#
# #### Real Estate (1 news)
#
# - LA fires: Landlords are price gouging, says 'Selling Sunset' star (Business Insider)
#
# #### Economic Policies (1 news)
#
# - New pay transparency regulations could help women negotiate better salaries (The Next Web)
#
# ### 🧠 Technology Innovations — Summary
# Sequoia PGP's transition to LGPL 2.0+ could enhance software accessibility and innovation, prompting broader adoption in tech sectors. Meanwhile, OpenAI's $38 billion deal with Amazon signals a significant investment in AI capabilities, which could accelerate advancements in cloud services and machine learning. As these developments unfold, they're likely to reshape competitive dynamics in technology and attract further venture capital into emerging hubs.
#
# ### 🧠 Political Dynamics — Summary
# Today, significant political moves include ongoing coalition talks in the Netherlands and the potential for a prolonged U.S. government shutdown, which could become the longest in history. These developments raise concerns about economic stability in Europe and potential disruptions to federal services and funding in the U.S. Looking ahead, continued political turbulence may affect investor confidence and economic policies in both regions.
#
# ### 🧠 Political Elections — Summary
# Today, voters in New Jersey, Virginia, and New York City participated in off-year elections, with Virginia poised to elect its first female governor and New York City deciding on its new mayor. These elections are critical as they may shape the political landscape and influence the 2026 midterms, particularly for Republicans aiming to maintain a House majority. The outcomes could signal shifts in voter sentiment and economic policies leading into the next electoral cycle.
#
#
# ✅ Summary sections saved to: news_summary_for_2025-11-05.txt
