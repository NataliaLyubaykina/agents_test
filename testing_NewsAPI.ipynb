# %% [markdown]
# #Parsing
#
# Apparently, most financial news websites **do not provide full or free APIs**.
# Some sites have **no public API at all**, and others place most of their content **behind paywalls**.
#
# There are tools, in this notebook I test [NewsAPI.org](https://newsapi.org/).

# %% [markdown]
# # Testing NewsAPI.org to aggregate news

# %% [markdown]
# ## How many sources can it aggregate for economic news from the US?

# %%
import requests
import pandas as pd

url = f"https://newsapi.org/v2/top-headlines/sources?apiKey={API_KEY}"

response = requests.get(url)
data = response.json()

if response.status_code != 200:
    print("Error:", data)
else:
    sources = data.get("sources", [])
    df = pd.DataFrame([{
        "id": s["id"],
        "name": s["name"],
        "category": s["category"],
        "language": s["language"],
        "country": s["country"],
        "url": s["url"],
        "description": s["description"]
    } for s in sources])

    # Filter for US + English
    df = df[(df["country"] == "us") & (df["language"] == "en")]

    # Keep relevant categories
    df = df[df["category"].isin(["business", "general", "technology", "science"])]

    # Manually tag most relevant economic/financial outlets
    relevance_keywords = [
        "finance", "business", "market", "money",
        "economy", "financial", "investment", "stock"
    ]

    df["is_economic"] = df["description"].str.contains(
        "|".join(relevance_keywords), case=False, na=False
    )

    econ_df = df[df["is_economic"]].copy()

    # Sort by category for overview
    econ_df = econ_df.sort_values(["category", "name"])
    econ_df = econ_df.reset_index(drop=True)

# %%
econ_df['id']
# Out:
# 0               bloomberg
# 1        business-insider
# 2                 fortune
# 3        associated-press
# 4                fox-news
# 5                nbc-news
# 6                newsweek
# 7                 reuters
# 8     the-washington-post
# 9             hacker-news
# 10           the-next-web
# 11                  wired
# Name: id, dtype: object

# %% [markdown]
# # Twelve sources - not bad

# %% [markdown]
# ## How many news for today can it agreggate from these sources?

# %%
from datetime import datetime, timezone, timedelta

# 🗓️ Get today's date in UTC (ISO 8601 compatible)
today = datetime.now(timezone.utc).strftime("%Y-%m-%d")
print(today)
# Out:
# 2025-11-03

# %%
# 🗞️ Collect all articles from your econ_df
all_articles = []

print(f"Fetching today's news ({today}) from {len(econ_df)} economic/financial sources...\n")

for source_id, source_name in zip(econ_df["id"], econ_df["name"]):
    url = (
        f"https://newsapi.org/v2/top-headlines?"
        f"sources={source_id}&"
        f"language=en&"
        f"pageSize=100&"
        f"apiKey={API_KEY}"
    )

    response = requests.get(url)
    data = response.json()

    if response.status_code != 200:
        print(f"❌ {source_name} ({source_id}): Error {response.status_code} → {data.get('message')}")
        continue

    articles = data.get("articles", [])
    print(f"✅ {source_name}: {len(articles)} articles")

    for a in articles:
        all_articles.append({
            "source_id": source_id,
            "source_name": source_name,
            "title": a["title"],
            "description": a["description"],
            "url": a["url"],
            "publishedAt": a["publishedAt"]
        })
# Out:
# Fetching today's news (2025-11-03) from 12 economic/financial sources...
#
# ✅ Bloomberg: 10 articles
# ✅ Business Insider: 10 articles
# ✅ Fortune: 10 articles
# ✅ Associated Press: 10 articles
# ✅ Fox News: 10 articles
# ✅ NBC News: 10 articles
# ✅ Newsweek: 10 articles
# ✅ Reuters: 0 articles
# ✅ The Washington Post: 10 articles
# ✅ Hacker News: 10 articles
# ✅ The Next Web: 7 articles
# ✅ Wired: 10 articles

# %%
if all_articles:
    news_df = pd.DataFrame(all_articles)

    # ✅ robust timestamp parsing
    news_df["publishedAt"] = pd.to_datetime(news_df["publishedAt"], format="ISO8601", errors="coerce")

    news_df = news_df.sort_values("publishedAt", ascending=False).reset_index(drop=True)

    print(f"\n✅ Total articles collected: {len(news_df)} from {news_df['source_name'].nunique()} sources.")
else:
    print("\n⚠️ No articles found for today.")
# Out:
# ✅ Total articles collected: 107 from 11 sources.

# %%
news_df.head()
# Out:
#           source_id       source_name  \
# 0  associated-press  Associated Press
# 1         bloomberg         Bloomberg
# 2          fox-news          Fox News
# 3  associated-press  Associated Press
# 4          fox-news          Fox News
#
#                                                title  \
# 0  Israel says the Red Cross has received the rem...
# 1  Tesla Owner Complaints Rise in US Probe Over I...
# 2  Mamdani's socialist allies embrace watchdog's ...
# 3  Trump says China's Xi has assured him that he ...
# 4  ESPN broadcasters roast Oklahoma kicker for we...
#
#                                          description  \
# 0  Israel says the Red Cross has received the rem...
# 1  The US auto safety regulator investigating whe...
# 2  Socialist organizers praised an anti-Mamdani g...
# 3  President Donald Trump says Chinese President ...
# 4  Oklahoma Sooners kicker Tate Sandell was the b...
#
#                                                  url  \
# 0  https://apnews.com/article/israel-hamas-hostag...
# 1  https://www.bloomberg.com/news/articles/2025-1...
# 2  https://www.foxnews.com/politics/mamdanis-soci...
# 3  https://apnews.com/article/trump-xi-china-taiw...
# 4  https://www.foxnews.com/sports/espn-broadcaste...
#
#                           publishedAt
# 0           2025-11-02 18:41:37+00:00
# 1           2025-11-02 18:15:20+00:00
# 2    2025-11-02 17:22:24.272071+00:00
# 3           2025-11-02 17:15:45+00:00
# 4 2025-11-02 17:07:24.538435400+00:00

# %% [markdown]
# ## Can already see that many articles are relevant, some local news

# %% [markdown]
# # Analysing the aggregated news

# %% [markdown]
# ## News categories defined by GPT model (using fixed topic list)

# %% [markdown]
# ### Fixed categories

# %%
# possible topics
topics = [
    "Monetary Policy",
    "Inflation",
    "Labor Market",
    "Corporate Earnings",
    "Stock Markets",
    "Energy Prices",
    "Real Estate",
    "Trade and Geopolitics",
    "Fiscal Policy",
    "Consumer Spending",
    "Banking and Credit",
    "Technology and Innovation",
    "Commodities",
    "Financial Regulation",
    "Auto Industry Issues", # added after check
    "Government Shutdown Effects"  # added after check
]

# %%
from openai import OpenAI
from tqdm import tqdm
import pandas as pd

client = OpenAI(api_key=my_gpt_key)

df = news_df.copy()
texts = (
    df["title"].fillna("") + ". " + df["description"].fillna("")
).tolist()

print(f"Using fixed {len(topics)} categories:\n{topics}\n")

# --- classification function ---
def classify_article(text, topics):
    prompt = f"""
You are an economics analyst.
Assign the following news item to the *closest* matching category from this list:
{', '.join(topics)}.

If it is not economic, financial, or business related, respond exactly with: "Other".
You must choose **exactly one** from the list if possible.

News:
{text}

Return only the category name exactly as in the list or "Not Economic".
"""
    r = client.chat.completions.create(
        model="gpt-4o-mini",
        temperature=0,  # 👈 stability: deterministic output
        messages=[{"role": "user", "content": prompt}],
    )
    return r.choices[0].message.content.strip()

# --- run classification ---
labels = []
for text in tqdm(texts, desc="Categorizing articles"):
    label = classify_article(text, topics)
    labels.append(label)

df["category"] = labels
print("✅ Classification complete.")
# Out:
# Using fixed 16 categories:
# ['Monetary Policy', 'Inflation', 'Labor Market', 'Corporate Earnings', 'Stock Markets', 'Energy Prices', 'Real Estate', 'Trade and Geopolitics', 'Fiscal Policy', 'Consumer Spending', 'Banking and Credit', 'Technology and Innovation', 'Commodities', 'Financial Regulation', 'Auto Industry Issues', 'Government Shutdown Effects']
# Categorizing articles: 100%|██████████| 107/107 [00:52<00:00,  2.05it/s]
# ✅ Classification complete.

# %% [markdown]
# ### Do these categories reflect news?

# %%
from openai import OpenAI
import re, ast
from datetime import datetime

client = OpenAI(api_key=my_gpt_key)

# --- use the same cleaned df you already have ---
sample_texts = (
    df["title"].fillna("") + ". " + df["description"].fillna("")
).tolist()[:50]  # sample first 50 items for context

# ===============================================================
# 1️⃣  GPT defines categories based on current news headlines
# ===============================================================
prompt_infer = f"""
You are an economics analyst.
Given these news headlines, identify 8–12 short, clear economic or financial categories
that best represent the topics covered. Use 2–3 word labels.

Headlines:
{chr(10).join(sample_texts)}

Return only a valid Python list of strings (no commentary).
"""

resp_infer = client.chat.completions.create(
    model="gpt-4o-mini",
    temperature=0,
    messages=[{"role": "user", "content": prompt_infer}],
)
raw_infer = resp_infer.choices[0].message.content.strip()

# --- clean and parse list ---
raw_infer = re.sub(r"^```[a-zA-Z]*", "", raw_infer).replace("```", "").strip()
try:
    inferred_categories = ast.literal_eval(raw_infer)
except Exception:
    inferred_categories = [c.strip() for c in raw_infer.split(",") if c.strip()]

print(f"\n🧩 GPT-inferred categories ({len(inferred_categories)}):\n{inferred_categories}\n")

# ===============================================================
# 2️⃣  Ask GPT to compare inferred vs. fixed lists
# ===============================================================
prompt_compare = f"""
Compare these two lists of economic categories.

Fixed categories:
{topics}

Newly inferred categories from data:
{inferred_categories}

Analyze whether the fixed list sufficiently covers the new ones.
If some inferred categories are missing or too distinct,
recommend which 1–3 additional categories (if any) should be added.

Be concise, and finish with a clear yes/no about whether to expand the list.
"""

resp_compare = client.chat.completions.create(
    model="gpt-4o-mini",
    temperature=0,
    messages=[{"role": "user", "content": prompt_compare}],
)
conclusion = resp_compare.choices[0].message.content.strip()

print("### 🧠 Category Coverage Analysis\n")
print(conclusion)
# Out:
# 🧩 GPT-inferred categories (12):
# ['Geopolitical Tensions', 'Auto Industry Issues', 'Socialism vs Capitalism', 'Government Shutdown', 'Drug Policy', 'Election Dynamics', 'Food Assistance Programs', 'Market Reforms', 'Investment Strategies', 'Bond Market Trends', 'Academic Integrity', 'Natural Disasters']
#
# ### 🧠 Category Coverage Analysis
#
# The fixed categories cover a broad range of economic topics, but there are some gaps when compared to the newly inferred categories. Specifically:
#
# 1. **Geopolitical Tensions** - While "Trade and Geopolitics" is included, the specific focus on geopolitical tensions is distinct and warrants its own category.
# 2. **Socialism vs Capitalism** - This ideological debate is not explicitly covered in the fixed list and is significant in economic discussions.
# 3. **Government Shutdown** - While "Government Shutdown Effects" is included, it may be beneficial to have a separate category for the event itself.
# 4. **Drug Policy** - This is not addressed in the fixed list and can have substantial economic implications.
# 5. **Election Dynamics** - This is also missing and can influence economic policies and market behavior.
# 6. **Food Assistance Programs** - This specific area is not covered in the fixed list.
# 7. **Market Reforms** - This is a distinct topic that is not explicitly mentioned.
# 8. **Investment Strategies** - This is a practical aspect of economics that is not included.
# 9. **Bond Market Trends** - This is a specific financial area not covered in the fixed list.
# 10. **Academic Integrity** - This is more of an educational concern and less directly related to economics.
# 11. **Natural Disasters** - This can have significant economic impacts but is not included in the fixed list.
#
# Based on this analysis, I recommend adding the following categories to the fixed list:
# 1. Geopolitical Tensions
# 2. Socialism vs Capitalism
# 3. Drug Policy
#
# Therefore, the answer is **yes**, the list should be expanded.

# %% [markdown]
# ## Summary for ecomomic news

# %%
df = df[df["category"] != "Other"].copy()
df = df.reset_index(drop=True)

# %%
prompt_summary = f"""
You are an economics journalist writing concise market briefs.
Read the following headlines about "{cat}" and produce a **short 2–3 sentence summary** only.

Summarize:
- What specifically happened today
- Why it matters economically
- What it could mean going forward

Use clear, factual language, keep it under 80 words total, and include key numbers or names if relevant.
Do NOT exceed three sentences.

Headlines:
{headlines}

Return only the summary text (no intro, no list, no formatting).
"""

# %%
# --- Setup ---
client = OpenAI(api_key=my_gpt_key)

# --- Time with timezone ---
tz_offset = timezone(timedelta(hours=1))  # set your offset here
current_time = datetime.now(tz=tz_offset).strftime("%Y-%m-%d %H:%M:%S (UTC+1)")

# --- Basic stats ---
total_econ = len(df)
source_counts = df["source_name"].value_counts().to_dict()
cat_counts = df["category"].value_counts()
cat_counts_dict = cat_counts.to_dict()

# --- Sort by most frequent categories ---
df["category"] = pd.Categorical(df["category"], categories=cat_counts.index, ordered=True)
df = df.sort_values("category")

# --- HEADER ---
print(f"### 🗓️ Daily Economic News Summary ({current_time})\n")
print(f"Till this time today, NewsAPI aggregated **{total_econ} economic news items**.\n")

# --- SOURCES ---
print("**Sources contributing (news count in brackets):**")
print(", ".join([f"{src} ({n})" for src, n in source_counts.items()]))
print("\n")

# --- CATEGORIES ---
print(f"GPT categorized them into **{len(cat_counts)} economic categories:**")
print(", ".join([f"{cat} ({count})" for cat, count in cat_counts_dict.items()]))
print("\n")

# --- HEADLINES BY CATEGORY ---
for cat in cat_counts.index:
    print(f"#### {cat} ({cat_counts_dict[cat]} news)\n")
    cat_df = df[df["category"] == cat]
    for _, row in cat_df.iterrows():
        print(f"- {row['title']} ({row['source_name']})")
    print()

# --- GPT SUMMARIES FOR TOP 3 CATEGORIES ---
top3 = cat_counts.head(3).index.tolist()

for cat in top3:
    cat_df = df[df["category"] == cat]
    headlines = "\n".join(cat_df["title"].tolist())

    prompt_summary = f"""
You are an economics journalist writing concise market briefs.
Read the following headlines about "{cat}" and produce a **short 2–3 sentence summary** only.

Summarize:
- What specifically happened today
- Why it matters economically
- What it could mean going forward

Use clear, factual language, keep it under 80 words total, and include key numbers or names if relevant.
Do NOT exceed three sentences.

Headlines:
{headlines}

Return only the summary text (no intro, no list, no formatting).
"""

    resp = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt_summary}],
    )

    summary = resp.choices[0].message.content.strip()
    print(f"### 🧠 {cat} — Summary\n{summary}\n")
# Out:
# ### 🗓️ Daily Economic News Summary (2025-11-03 20:09:49 (UTC+1))
#
# Till this time today, NewsAPI aggregated **38 economic news items**.
#
# **Sources contributing (news count in brackets):**
# Bloomberg (10), The Next Web (7), Business Insider (5), Fortune (4), Wired (3), Associated Press (3), Newsweek (2), Hacker News (1), The Washington Post (1), Fox News (1), NBC News (1)
#
#
# GPT categorized them into **11 economic categories:**
# Technology and Innovation (12), Trade and Geopolitics (7), Stock Markets (5), Fiscal Policy (2), Auto Industry Issues (2), Energy Prices (2), Banking and Credit (2), Corporate Earnings (2), Labor Market (2), Government Shutdown Effects (1), Real Estate (1)
#
#
# #### Technology and Innovation (12 news)
#
# - THE AI ISSUE (Wired)
# - EU's EV battery ambitions hang in the balance (The Next Web)
# - 3D-printed rocket engine revs up for orbital launch in Scotland (The Next Web)
# - A metaverse network plots an escape from Meta's 'walled gardens' (The Next Web)
# - This startup gives your speech a new 'human-realistic' AI voice — for free (The Next Web)
# - Mobility giant Bolt adopts self-driving Starship robots for food delivery (The Next Web)
# - Blockchain giant Chainalysis acquires AI agent startup Alterya (Business Insider)
# - The next Silicon Valley may not exist. Here’s what smaller hubs can do to attract VC dollars (Fortune)
# - AI AS PR (Wired)
# - AI AS BUBBLE (Wired)
# - Nexperia China Says It Has Enough Stock Despite Supply Halt (Bloomberg)
# - bigscience/T0pp · Hugging Face (Hacker News)
#
# #### Trade and Geopolitics (7 news)
#
# - Trump Military Attack on Venezuelan Boat Intends To Redefine War | Opinion (Newsweek)
# - Venezuela Speaks Out on Trump's Drug Boat Attack: 'Murder' (Newsweek)
# - Supreme Court has empowered Donald Trump. How much further will it go? (The Washington Post)
# - Rapid delivery giant Getir quits France, citing regulation hurdles (The Next Web)
# - 4 vital steps that U.S. CEOs must take in the economic battle with China (Fortune)
# - 2 people killed in Ukraine’s Odesa region as Russia continues to target power grid (Associated Press)
# - Trump says China's Xi has assured him that he won't take action on Taiwan during Republican's term (Associated Press)
#
# #### Stock Markets (5 news)
#
# - Why investors shouldn't worry about stretched stock market valuations: BofA (Business Insider)
# - AI Rally and Volatility Define Stock Run Since Trump’s Return (Bloomberg)
# - Green Investors Enjoy Huge Returns That Defy Trump Attacks (Bloomberg)
# - Saudi Stocks Extend Losses on Caution Over Market Reforms (Bloomberg)
# - Investors Eye Quick-Twitch Quant Strategies to Handle Next Shock (Bloomberg)
#
# #### Fiscal Policy (2 news)
#
# - Charts illustrate the scale of SNAP as millions face potential benefit lapse (Fox News)
# - Ending SNAP could hit Black Americans the hardest (Associated Press)
#
# #### Auto Industry Issues (2 news)
#
# - BMW and Porsche have a China problem. They're not the only ones. (Business Insider)
# - Tesla Owner Complaints Rise in US Probe Over Inoperative Doors (Bloomberg)
#
# #### Energy Prices (2 news)
#
# - OPEC+ to Approve Small Output Hike for December, Delegates Say (Bloomberg)
# - Russian Oil Tanker Set Ablaze in Drone Attack on Black Sea Port (Bloomberg)
#
# #### Banking and Credit (2 news)
#
# - Troubled Nations Mount Comeback to Debt Markets Amid Yield Hunt (Bloomberg)
# - UK Bonds’ Best Run in Two Years Is Winning Over Global Investors (Bloomberg)
#
# #### Corporate Earnings (2 news)
#
# - Unprofitable companies needed to be profitable yesterday (Fortune)
# - Buybacks vs dividends? In market downturns, the rules may change (Fortune)
#
# #### Labor Market (2 news)
#
# - New pay transparency regulations could help women negotiate better salaries (The Next Web)
# - 5 do's and don'ts to land a job in the private-credit boom (Business Insider)
#
# #### Government Shutdown Effects (1 news)
#
# - Poll: Republicans shoulder more shutdown blame, as signs of voter irritation with both parties pile up (NBC News)
#
# #### Real Estate (1 news)
#
# - LA fires: Landlords are price gouging, says 'Selling Sunset' star (Business Insider)
#
# ### 🧠 Technology and Innovation — Summary
# Today, notable advancements in technology include the launch of 3D-printed rocket engines in Scotland and EU discussions on electric vehicle battery production. These developments are critical as they signify ongoing innovation in sustainable technologies and may enhance the region's competitiveness in emerging markets. Additionally, the rise of AI-driven services, like those from startups providing free voice technology, could reshape industries and attract investment in smaller tech hubs.
#
# ### 🧠 Trade and Geopolitics — Summary
# Today, tensions escalated as Trump authorized a military strike on a Venezuelan vessel linked to drug trafficking, prompting a strong response from Venezuela condemning the action as "murder." This aggressive stance reflects broader geopolitical tensions and could impact trade relations, particularly concerning drug enforcement and military activities in Latin America. Additionally, other international dynamics, including U.S.-China relations and the ongoing conflict in Ukraine, underscore the fragile economic landscape and the potential for further disruptions in trade and investment.
#
# ### 🧠 Stock Markets — Summary
# Today, stock markets showed volatility amid caution, particularly in Saudi stocks which extended losses due to uncertainty over market reforms. Bank of America reassured investors about high valuations, while an ongoing AI rally continues to drive returns despite geopolitical tensions. Looking ahead, the adoption of quick-twitch quant strategies may become essential for investors seeking to navigate potential market shocks.
